# %% [markdown]
# # Исследовательский анализ топ 200 YouTube-блогеров
#
# В данном проекте был произведен импорт и первичная обработка данных о 200 крупнейших каналов YouTube (с точки зрения количества просмотров), а так же произведен исследовательский анализ данных с визуализацией полученных результатов.
#
# <b>Целью проекта</b> является исследование данных о 200 крупнейших YouTube каналов относительно их географии, популярности тех или иных жанров и категорий каналов, общего количества лайков и просмотров, а также уровня вовлеченности подписчиков.
#
# <b>Описание данных:</b>
#
#  - `Country`: Name of the country ('IN', 'US', 'KR', 'CA', 'BR', 'MX', 'SV', 'CL', 'NO', 'PR', 'BY', 'RU', 'PH', 'TH', 'AE', 'CO', 'ES', 'GB', 'AR', 'ID', 'NL','ES', 'IE', 'PK', 'AU', 'KW', 'SO')
#  - `Channel Name`: Name of the channel
#  - `Category`: Category ('Gaming & Apps','Sports', 'Music', 'Beauty & Fashion', 'Science & Tech', 'Fashion', 'LifeStyle')
#  - `Main Video Category`: ('Music', 'Education', 'Shows', 'Gaming', 'Entertainment', 'People & Blogs', 'Sports', 'Howto & Style', 'Film & Animation', 'News & Politics', 'Pop music', 'Comedy', 'Nonprofits & Activism', 'Action-adventure game', 'Strategy video game', 'TV shows')
#  - `Username`: Username of the youtube channel
#  - `Followers`: No. of followers
#  - `Main topic`: Topic that has been discussed more.
#  - `More Topics`: Topics apart from main topic.
#  - `Likes`: Total Likes
#  - `Boost Index`: Boost index value.
#  - `Engagement Rate`: Rate of engagement with the users.
#  - `Engagement Rate 60days`: Rate of engagement with the users for 60 days
#  - `View`: Total Views
#  - `Views. Avg`: Average views
#  - `Avg. 1 Day`: Average views for one day
#  - `Avg. 3 Day`: Average views for 3 days
#  - `Avg. 7 Day`: Average views for 7 days
#  - `Avg. 14 Day`: Average views for 14 days
#  - `Avg. 30 Day`: Average view for 30 days
#  - `Avg. 60 Day`: Average view for 60 days
#  - `Comments Avg`: Average comments.
#  - `Youtube Link`: Link of the channel

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Импорт библиотек
# <b>Первоначально импортируем все необходимые нам библиотеки:</b>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
pd.set_option('display.max_columns', 22)

# %% [markdown]
# ### Импорт данных
# <b>Для начала сохраним данные в DataFrame и посмотрим информацию о нем.</b>

# %%
folders = Path.cwd()
file_name = Path(folders, 'top_200_youtubers.csv')

df = pd.read_csv(file_name)

# %% [markdown]
# Найдем размер таблицы:

# %%
size = df.shape
display(size)
# Out:
# (857, 22)

# %% [markdown]
# Посмотрим информацию о содержащихся данных:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 707 non-null    object
#  1   Channel Name            857 non-null    object
#  2   Category                736 non-null    object
#  3   Main Video Category     855 non-null    object
#  4   username                857 non-null    object
#  5   followers               857 non-null    int64
#  6   Main topic              855 non-null    object
#  7   More topics             855 non-null    object
#  8   Likes                   857 non-null    float64
#  9   Boost Index             857 non-null    int64
#  10  Engagement Rate         855 non-null    float64
#  11  Engagement Rate 60days  857 non-null    float64
#  12  Views                   857 non-null    int64
#  13  Views Avg.              855 non-null    float64
#  14  Avg. 1 Day              494 non-null    float64
#  15  Avg. 3 Day              652 non-null    float64
#  16  Avg. 7 Day              741 non-null    float64
#  17  Avg. 14 Day             779 non-null    float64
#  18  Avg. 30 day             815 non-null    float64
#  19  Avg. 60 day             857 non-null    float64
#  20  Comments Avg            855 non-null    float64
#  21  Youtube Link            857 non-null    object
# dtypes: float64(11), int64(3), object(8)
# memory usage: 147.4+ KB

# %% [markdown]
# Выведем первые 10 строк таблицы, что посмотреть на данные:

# %%
df.head(10)
# Out:
#   Country               Channel Name       Category Main Video Category  \
# 0      IN                   T-Series  Gaming & Apps               Music
# 1      US  ABCkidTV - Nursery Rhymes  Gaming & Apps           Education
# 2      IN                  SET India  Gaming & Apps               Shows
# 3      US                  PewDiePie  Gaming & Apps              Gaming
# 4      US                    MrBeast  Gaming & Apps       Entertainment
# 5      US                Like Nastya            NaN      People & Blogs
# 6      US          ✿ Kids Diana Show  Gaming & Apps       Entertainment
# 7      IN                   T-Series  Gaming & Apps               Music
# 8      US  ABCkidTV - Nursery Rhymes  Gaming & Apps           Education
# 9      IN                  SET India  Gaming & Apps               Shows
#
#                     username  followers     Main topic  \
# 0                   T-Series  220000000  Music of Asia
# 1  ABCkidTV - Nursery Rhymes  138000000         Movies
# 2                  SET India  137000000         Movies
# 3                  PewDiePie  111000000      Lifestyle
# 4                    MrBeast   98100000      Lifestyle
# 5                Like Nastya   97300000          Hobby
# 6          ✿ Kids Diana Show   97200000      Lifestyle
# 7                   T-Series  220000000  Music of Asia
# 8  ABCkidTV - Nursery Rhymes  138000000         Movies
# 9                  SET India  137000000         Movies
#
#                                          More topics         Likes  \
# 0           Entertainment,Music of Asia,Music,Movies  1.602680e+09
# 1                         Entertainment,Music,Movies  2.209901e+08
# 2                Entertainment,TV shows,Music,Movies  1.748752e+08
# 3  Gaming,Action game,Lifestyle,Action-adventure ...  2.191406e+09
# 4                 Entertainment,Lifestyle,Technology  1.731833e+09
# 5                                    Lifestyle,Hobby  2.808777e+08
# 6                                    Lifestyle,Hobby  2.351904e+08
# 7           Entertainment,Music of Asia,Music,Movies  1.602680e+09
# 8                         Entertainment,Music,Movies  2.209901e+08
# 9                Entertainment,TV shows,Music,Movies  1.748752e+08
#
#    Boost Index  Engagement Rate  Engagement Rate 60days         Views  \
# 0           83         0.033463                0.010879  195660744416
# 1           63         0.641716                0.116004  133025325473
# 2           79         0.001206                0.002366  121741739317
# 3           88         0.063426                0.044846   28424113942
# 4           60         0.729210                0.570270   16242634269
# 5           79         1.026761                0.231388   80111555805
# 6           67         0.690342                0.243853   77340155581
# 7           83         0.033463                0.010879  195660744416
# 8           63         0.641716                0.116004  133025325473
# 9           79         0.001206                0.002366  121741739317
#
#      Views Avg.    Avg. 1 Day   Avg. 3 Day    Avg. 7 Day   Avg. 14 Day  \
# 0  2.095329e+06  1.522448e+05  2134569.625  1.809830e+06  2.306178e+06
# 1  7.027126e+07  1.837916e+06  1837916.000  4.891832e+06  7.052576e+06
# 2  1.095729e+05           NaN   586040.000  2.801276e+05  3.437881e+05
# 3  7.718345e+06           NaN          NaN  3.497395e+06  3.094440e+06
# 4  9.876250e+07           NaN          NaN  2.994102e+07  2.994102e+07
# 5  1.381637e+08           NaN  3946868.000  5.829929e+06  9.480138e+06
# 6  8.641735e+07           NaN          NaN  7.539490e+06  9.148088e+06
# 7  2.095329e+06  1.522448e+05  2134569.625  1.809830e+06  2.306178e+06
# 8  7.027126e+07  1.837916e+06  1837916.000  4.891832e+06  7.052576e+06
# 9  1.095729e+05           NaN   586040.000  2.801276e+05  3.437881e+05
#
#     Avg. 30 day   Avg. 60 day   Comments Avg              Youtube Link
# 0  1.676330e+06  2.295416e+06    4493.984146  UCq-Fj5jknLsUf-MWSy4_brA
# 1  1.265433e+07  1.572284e+07     146.700252  UCbCmjCuTUZos6Inko4u57UQ
# 2  3.536019e+05  3.220336e+05      76.244316  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  3.620274e+06  4.454120e+06   35839.781347  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 4  2.994102e+07  5.343473e+07  113432.373684  UCX6OQ3DkcsbYNE6H8uQQuVA
# 5  1.375691e+07  2.210875e+07       0.292490  UCJplp5SjeGSdVdwsfb9Q7lQ
# 6  1.434739e+07  2.346710e+07       0.000000  UCk8GzjMOrta8yxDcKfylJYw
# 7  1.676330e+06  2.295416e+06    4493.984146  UCq-Fj5jknLsUf-MWSy4_brA
# 8  1.265433e+07  1.572284e+07     146.700252  UCbCmjCuTUZos6Inko4u57UQ
# 9  3.536019e+05  3.220336e+05      76.244316  UCpEhnqL0y41EpW2TvWAHD7Q

# %% [markdown]
# Можно заметить, что в данных имеются дубликаты, а также в некоторых полях пропущены значения.

# %% [markdown]
# ### Удаление дубликатов
# Удалим дубликаты и посмотрим как изменился наш набор данных:

# %%
df = df.drop_duplicates().reset_index(drop=True)
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 164 non-null    object
#  1   Channel Name            200 non-null    object
#  2   Category                164 non-null    object
#  3   Main Video Category     199 non-null    object
#  4   username                200 non-null    object
#  5   followers               200 non-null    int64
#  6   Main topic              199 non-null    object
#  7   More topics             199 non-null    object
#  8   Likes                   200 non-null    float64
#  9   Boost Index             200 non-null    int64
#  10  Engagement Rate         199 non-null    float64
#  11  Engagement Rate 60days  200 non-null    float64
#  12  Views                   200 non-null    int64
#  13  Views Avg.              199 non-null    float64
#  14  Avg. 1 Day              117 non-null    float64
#  15  Avg. 3 Day              153 non-null    float64
#  16  Avg. 7 Day              172 non-null    float64
#  17  Avg. 14 Day             182 non-null    float64
#  18  Avg. 30 day             191 non-null    float64
#  19  Avg. 60 day             200 non-null    float64
#  20  Comments Avg            199 non-null    float64
#  21  Youtube Link            200 non-null    object
# dtypes: float64(11), int64(3), object(8)
# memory usage: 34.5+ KB
# (200, 22)

# %% [markdown]
# После удаления дубликатов размер таблицы заметно уменьшился. Однако видно, что в столбцах <b><i>Country, Category,Main vedio category, Main vedio topics, More topics, Engagement Rates,Views avg, Avg.1 Day,Avg. 3 Day, Avg. 7 Day, Avg. 14 Day, Avg. 30 Day, Comments Avg</i></b> присутствуют пустые значения. Их необходимо обработать.

# %% [markdown]
# ### Обработка пустых значений
#
# Достаточный интерес представляют столбцы, в которых остутствует всего одно значение (такие как Main topic, More topics, Engagement Rate, Comments Avg и др.). Возможно в массиве данных есть какая-то одна строка со всеми незаполненными полями? Проверим:

# %%
display(df[df['Main topic'].isna() == True])
# Out:
#    Country Channel Name Category Main Video Category username  followers  \
# 75     NaN         News      NaN                 NaN     News   36100000
#
#    Main topic More topics  Likes  Boost Index  Engagement Rate  \
# 75        NaN         NaN    0.0           85              NaN
#
#     Engagement Rate 60days  Views  Views Avg.  Avg. 1 Day  Avg. 3 Day  \
# 75                     0.0      0         NaN         0.0         0.0
#
#     Avg. 7 Day  Avg. 14 Day  Avg. 30 day  Avg. 60 day  Comments Avg  \
# 75         0.0          0.0          0.0          0.0           NaN
#
#                 Youtube Link
# 75  UCYfdidRxbB8Qhf0Nx7ioOYw

# %% [markdown]
# Действительно, практически все поля в этой строке не имеют значний. Такого рода строка нерепрезентативна, поэтому ее можно удалить:

# %%
df = df.drop(labels=75, axis=0)

# %% [markdown]
# <b>Найдем долю количества пропущенных значений:</b>

# %%
count_col = df.shape[0]
round(((1-df.count()/count_col)*100),1).sort_values(ascending=False)
# Out:
# Avg. 1 Day                41.7
# Avg. 3 Day                23.6
# Country                   17.6
# Category                  17.6
# Avg. 7 Day                14.1
# Avg. 14 Day                9.0
# Avg. 30 day                4.5
# Views                      0.0
# Comments Avg               0.0
# Avg. 60 day                0.0
# Views Avg.                 0.0
# Engagement Rate 60days     0.0
# Channel Name               0.0
# Engagement Rate            0.0
# Boost Index                0.0
# Likes                      0.0
# More topics                0.0
# Main topic                 0.0
# followers                  0.0
# username                   0.0
# Main Video Category        0.0
# Youtube Link               0.0
# dtype: float64

# %% [markdown]
# Среди тех полей, в которых отсутствуют значения можно выделить категориальные переменные, такие как <b><i>Country, Category</i></b>, так и количественные, по типу <b><i>Avg.1 Day,Avg. 3 Day, Avg. 7 Day, Avg. 14 Day, Avg. 30 Day</i></b>.
# Для заполнения количественных переменных воспользуемся средним значением, в зависимости от главной тематики видео:

# %%
df['Avg. 1 Day'] = df.groupby(['Main topic'])['Avg. 1 Day'].transform(lambda x : x.fillna(x.mean()))
df['Avg. 3 Day'] = df.groupby(['Main topic'])['Avg. 3 Day'].transform(lambda x : x.fillna(x.mean()))
df['Avg. 7 Day'] = df.groupby(['Main topic'])['Avg. 7 Day'].transform(lambda x : x.fillna(x.mean()))
df['Avg. 14 Day'] = df.groupby(['Main topic'])['Avg. 14 Day'].transform(lambda x : x.fillna(x.mean()))
df['Avg. 30 day'] = df.groupby(['Main topic'])['Avg. 30 day'].transform(lambda x : x.fillna(x.mean()))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 199
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 164 non-null    object
#  1   Channel Name            199 non-null    object
#  2   Category                164 non-null    object
#  3   Main Video Category     199 non-null    object
#  4   username                199 non-null    object
#  5   followers               199 non-null    int64
#  6   Main topic              199 non-null    object
#  7   More topics             199 non-null    object
#  8   Likes                   199 non-null    float64
#  9   Boost Index             199 non-null    int64
#  10  Engagement Rate         199 non-null    float64
#  11  Engagement Rate 60days  199 non-null    float64
#  12  Views                   199 non-null    int64
#  13  Views Avg.              199 non-null    float64
#  14  Avg. 1 Day              193 non-null    float64
#  15  Avg. 3 Day              197 non-null    float64
#  16  Avg. 7 Day              198 non-null    float64
#  17  Avg. 14 Day             199 non-null    float64
#  18  Avg. 30 day             199 non-null    float64
#  19  Avg. 60 day             199 non-null    float64
#  20  Comments Avg            199 non-null    float64
#  21  Youtube Link            199 non-null    object
# dtypes: float64(11), int64(3), object(8)
# memory usage: 35.8+ KB

# %% [markdown]
# Видно, что в столбцах <b><i>Avg.1 Day,Avg. 3 Day, Avg. 7 Day</i></b> остались пустые значения. Это связано с тем, что по некоторым категориям все значения были пустыми и среднее не могло быть рассчитано. Для них воспользуемся средним значением по всему полю:

# %%
df['Avg. 1 Day'] = df['Avg. 1 Day'].fillna(df['Avg. 1 Day'].mean())
df['Avg. 3 Day'] = df['Avg. 3 Day'].fillna(df['Avg. 3 Day'].mean())
df['Avg. 7 Day'] = df['Avg. 7 Day'].fillna(df['Avg. 7 Day'].mean())
df.describe()
# Out:
#           followers         Likes  Boost Index  Engagement Rate  \
# count  1.990000e+02  1.990000e+02   199.000000       199.000000
# mean   3.949447e+07  1.822127e+08    64.874372         0.460653
# std    2.267856e+07  3.089295e+08    16.467271         1.072026
# min    2.400000e+07  0.000000e+00     1.000000         0.000261
# 25%    2.740000e+07  2.479022e+07    60.000000         0.027500
# 50%    3.250000e+07  7.100074e+07    70.000000         0.120258
# 75%    4.215000e+07  1.857181e+08    76.000000         0.463765
# max    2.200000e+08  2.191406e+09    88.000000        10.584084
#
#        Engagement Rate 60days         Views    Views Avg.    Avg. 1 Day  \
# count              199.000000  1.990000e+02  1.990000e+02  1.990000e+02
# mean                 0.077000  2.081041e+10  1.663930e+07  1.675266e+05
# std                  0.177622  2.125182e+10  4.082130e+07  3.405935e+05
# min                  0.000028  9.944180e+08  6.806065e+02  0.000000e+00
# 25%                  0.006230  1.155030e+10  6.865489e+05  1.058506e+04
# 50%                  0.025626  1.638087e+10  2.911653e+06  7.370850e+04
# 75%                  0.065306  2.322844e+10  1.433392e+07  1.889808e+05
# max                  1.519044  1.956607e+11  4.239235e+08  3.472638e+06
#
#          Avg. 3 Day    Avg. 7 Day   Avg. 14 Day   Avg. 30 day   Avg. 60 day  \
# count  1.990000e+02  1.990000e+02  1.990000e+02  1.990000e+02  1.990000e+02
# mean   4.647165e+05  9.301166e+05  1.740344e+06  2.219552e+06  2.727980e+06
# std    8.912526e+05  2.548751e+06  5.796456e+06  6.416406e+06  7.032095e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.711729e+04  2.604973e+04  4.769466e+04  7.682301e+04  9.492276e+04
# 50%    1.359740e+05  2.063635e+05  2.780231e+05  4.263303e+05  5.455273e+05
# 75%    5.713045e+05  7.002235e+05  1.098052e+06  1.884944e+06  2.053867e+06
# max    6.596001e+06  2.994102e+07  6.877732e+07  6.877732e+07  5.383523e+07
#
#         Comments Avg
# count     199.000000
# mean    13733.150460
# std     29601.444784
# min         0.000000
# 25%        51.868650
# 50%      1209.178571
# 75%     12120.383323
# max    199523.467742

# %% [markdown]
# <b>Посмотрим на строки набора данных, в которых не указана категория канала:</b>

# %%
display(df[df['Category'].isna() == True])
# Out:
#     Country                              Channel Name Category  \
# 5        US                               Like Nastya      NaN
# 9        US                             Vlad and Niki      NaN
# 32      NaN                             Ariana Grande      NaN
# 52       US                          Like Nastya Show      NaN
# 64       IN                                 Voot Kids      NaN
# 67       US                              xxxtentacion      NaN
# 72      NaN                                   Shakira      NaN
# 74       US                           Toys and Colors      NaN
# 77      NaN                                  Maroon 5      NaN
# 79       AE                               shfa2 - شفا      NaN
# 81       IN                         Jkk Entertainment      NaN
# 88       CO                                  J Balvin      NaN
# 94       IN                              Total Gaming      NaN
# 99       IN                                  Geet MP3      NaN
# 104      IN                          KHANDESHI MOVIES      NaN
# 106      MX                                    GENIAL      NaN
# 110     NaN                              Selena Gomez      NaN
# 111      US                                Luis Fonsi      NaN
# 121      ID                                        AH      NaN
# 126      US                                     Dream      NaN
# 131      US                                    Maluma      NaN
# 137      US                            ImagineDragons      NaN
# 141      US                            MrBeast Gaming      NaN
# 148      IN                             Techno Gamerz      NaN
# 152      US                                 TheDonato      NaN
# 153      PH                                GMANetwork      NaN
# 155      IN                                Round2hell      NaN
# 159      IN                         MR. INDIAN HACKER      NaN
# 167      KW                                   AboFlah      NaN
# 170      US                        Diana and Roma ESP      NaN
# 173      US                           व्लाद और निकिता      NaN
# 177      US                            Vlad và Nikita      NaN
# 186      ID                             Jess No Limit      NaN
# 191      US  Super JoJo - Nursery Rhymes & Kids Songs      NaN
# 197      IN                              Amit Bhadana      NaN
#
#        Main Video Category                                  username  \
# 5           People & Blogs                               Like Nastya
# 9            Entertainment                             Vlad and Niki
# 32               Pop music                             Ariana Grande
# 52           Entertainment                          Like Nastya Show
# 64           Entertainment                                 Voot Kids
# 67                   Music                              xxxtentacion
# 72          People & Blogs                                   Shakira
# 74           Entertainment                           Toys and Colors
# 77                   Music                                  Maroon 5
# 79          People & Blogs                               shfa2 - شفا
# 81                  Comedy                         Jkk Entertainment
# 88                   Music                                  J Balvin
# 94                  Gaming                              Total Gaming
# 99                   Music                                  Geet MP3
# 104                 Comedy                          KHANDESHI MOVIES
# 106          Howto & Style                                    GENIAL
# 110          Entertainment                              Selena Gomez
# 111          Entertainment                                Luis Fonsi
# 121          Entertainment                                        AH
# 126  Action-adventure game                                     Dream
# 131                  Music                                    Maluma
# 137                  Music                            ImagineDragons
# 141    Strategy video game                            MrBeast Gaming
# 148                 Gaming                             Techno Gamerz
# 152          Entertainment                                 TheDonato
# 153               TV shows                                GMANetwork
# 155                 Comedy                                Round2hell
# 159         People & Blogs                         MR. INDIAN HACKER
# 167                 Gaming                                   AboFlah
# 170          Entertainment                        Diana and Roma ESP
# 173          Entertainment                           व्लाद और निकिता
# 177          Entertainment                            Vlad và Nikita
# 186                 Gaming                             Jess No Limit
# 191              Education  Super JoJo - Nursery Rhymes & Kids Songs
# 197          Entertainment                              Amit Bhadana
#
#      followers               Main topic  \
# 5     97300000                    Hobby
# 9     83500000                    Hobby
# 32    51500000                Pop music
# 52    41300000                Lifestyle
# 64    38100000            Entertainment
# 137  1.277620e+05  1.277620e+05    1209.178571  UCT9zcQNlyht7fRlcjmflRSA
# 141  1.018683e+07  1.282855e+07   54156.775194  UCIPPMRA040LQr5QPyJEbmXA
# 148  7.033370e+06  7.812999e+06   32943.270968  UCX8pnu3DYUnx8qy8V_c6oHg
# 152  4.300728e+05  5.266031e+05    7351.350442  UCaHEdZtk6k7SVP-umnzifmQ
# 153  4.518435e+04  6.228550e+04      35.874548  UCKL5hAuzgFQsyrsQKgU0Qng
# 155  4.959616e+05  3.873975e+07   67627.326531  UCt4atlExw8aj3Bm79nv1fig
# 159  7.215870e+06  7.338308e+06   15507.884956  UCSiDGb0MnHFGjs4E2WKvShw
# 167  4.213971e+06  4.806892e+06   35452.389831  UCqq5n-Oe-r1EEHI3yvhVJcA
# 170  1.923809e+06  2.707562e+06       0.000000  UCqNmJfc7RgMU6hTxOOuCYHQ
# 173  8.943439e+05  1.300581e+06       0.000000  UCUMxxg0KvWiSWHUXRPpnKzw
# 177  1.857361e+06  3.977412e+06       0.000000  UCcOMTVILq-yIqtFmOqt-QOg
# 186  6.830365e+05  1.092899e+06   17449.325777  UCvh1at6xpV1ytYOAzxmqUsA
# 191  6.091040e+05  6.091040e+05      26.613744  UCHN9P-CQVBQ1ba8o1NQJVCA
# 197  0.000000e+00  0.000000e+00  100248.500000  UC_vcKmg67vjMP7ciLnSxSHQ

# %% [markdown]
# Можно с достаточной уверенностью сказать, что каналы, которые в `Main Video Category` имеют <b><i>Music</i></b> или <b><i>Pop music</i></b> можно отнести к категории <b><i>Music</i></b>. Аналогично <b><i>Gaming, Strategy video game</i></b> и <b><i>Action-adventure game</i></b> можно отнести к категории <b><i>Gaming & Apps</i></b>, а <b><i>Sports</i></b> к <b><i>Sports</i></b>. Кроме того, с большой нятяжкой, можно отнести <b><i>Education</i></b> к <b><i>Science & Tech:</i></b>

# %%
df.loc[((df['Category'].isna() == True) | (df['Category']=='None')) &
            ((df['Main Video Category']=='Music') | 
             (df['Main Video Category']=='Pop music')),'Category'] = 'Music'

df.loc[((df['Category'].isna() == True) | (df['Category']=='None')) &
           ((df['Main Video Category']=='Gaming') | 
            (df['Main Video Category']=='Strategy video game') | 
            (df['Main Video Category']=='Action-adventure game')),'Category'] = 'Gaming & Apps'

df.loc[((df['Category'].isna() == True) | (df['Category']=='None')) & 
            (df['Main Video Category']=='Sports'),'Category'] = 'Sports'

df.loc[((df['Category'].isna() == True) | (df['Category']=='None')) & 
           (df['Main Video Category']=='Education'),'Category'] = 'Science & Tech'

df.loc[((df['Category'].isna() == True) | (df['Category']=='None')) & 
           ((df['Main Video Category']=='People & Blogs') | 
            (df['Main Video Category']=='Howto & Style')),'Category'] = 'LifeStyle'

# %% [markdown]
# Однако все равно остаются категории видео, такие как <b><i>Shows, TV shows, Entertainment, Comedy</i></b> и др. Поэтому предлагаю ввести дополнительную категорию каналов - <b><i>Entertainment</i></b> и <b><i>Other:</i></b>

# %%
df.loc[((df['Category'].isna() == True) | (df['Category']=='None')) & 
           ((df['Main Video Category']=='Shows') | 
            (df['Main Video Category']=='TV shows') | 
            (df['Main Video Category']=='Entertainment') |
            (df['Main Video Category']=='Comedy') | 
            (df['Main Video Category']=='Film & Animation')),'Category'] = 'Entertainment'

df.loc[((df['Category'].isna() == True) | (df['Category']=='None')) & 
           ((df['Main Video Category']=='News & Politics') | 
            (df['Main Video Category']=='Nonprofits & Activism')),'Category'] = 'Other'

# %% [markdown]
# К сожалению заполнить пропуски в `Country` исходя из текущего набора данных мы не можем. Исключать из набора данных строки с пропусками в `Country` мы тоже не можем, т.к. они составляют 18% от общей выборки. Конечно, мы можем заполнить их основываясь на предположении, что Maron 5, например, являясь американской группой и создавая YouTube канал укажет в качестве страны США, а Shakira - Колумбию, но так как наша цель - проведение первичного исследовательского анализа, думаю можно заменить пустые значения на <b><i>unfilled</i></b>. А при необходимости более глубокого ислледования в дальнейшем, можно будет выбрать более подхоящий способ заполнения региона.

# %%
df['Country'] = df['Country'].fillna('unfilled')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 199
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 199 non-null    object
#  1   Channel Name            199 non-null    object
#  2   Category                199 non-null    object
#  3   Main Video Category     199 non-null    object
#  4   username                199 non-null    object
#  5   followers               199 non-null    int64
#  6   Main topic              199 non-null    object
#  7   More topics             199 non-null    object
#  8   Likes                   199 non-null    float64
#  9   Boost Index             199 non-null    int64
#  10  Engagement Rate         199 non-null    float64
#  11  Engagement Rate 60days  199 non-null    float64
#  12  Views                   199 non-null    int64
#  13  Views Avg.              199 non-null    float64
#  14  Avg. 1 Day              199 non-null    float64
#  15  Avg. 3 Day              199 non-null    float64
#  16  Avg. 7 Day              199 non-null    float64
#  17  Avg. 14 Day             199 non-null    float64
#  18  Avg. 30 day             199 non-null    float64
#  19  Avg. 60 day             199 non-null    float64
#  20  Comments Avg            199 non-null    float64
#  21  Youtube Link            199 non-null    object
# dtypes: float64(11), int64(3), object(8)
# memory usage: 35.8+ KB

# %% [markdown]
# Отлично! Все значния заполнены, значит можно приступать к визуализации данных.

# %% [markdown]
# ## Анализ и визуализация

# %%
#sns.displot(df['Views'], kde=True,bins=20)
plt.figure(figsize=(17,7))

custom_params ={"lines.linewidth": 3, 
                "axes.spines.left": False,
                "axes.spines.bottom": False, 
                "axes.spines.right": False, 
                "axes.spines.top": False} 
sns.set(style="white", font='Segoe UI',font_scale=1.15,rc=custom_params)

#график по кол-ву каналов в странах
country = df.groupby('Country')['Channel Name'].count().sort_values(ascending=False).head(10)
sns.barplot(data=df, x=country.index, y=country, color='#CABBE9')
plt.xlabel('')
plt.ylabel('')
plt.yticks([])
plt.title('Количество каналов из топ 200 по странам')
for i, val in enumerate(country.values):
    plt.text(i, val, val, horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':500, 'size':14})
plt.show()    

main_topic = df['Main topic'].value_counts().head(10)
category = df['Category'].value_counts()

plt.figure(figsize=(20,10))

#график топ категорий каналов
plt.subplot(1,2,1)
sns.barplot(data=df, x=category, y=category.index, color='#FFCEF3')
plt.title('Топ категорий по кол-ву блогеров')
plt.xlabel('')
plt.xticks([])
for i, val in enumerate(category.values):
    plt.text(val+2, i+0.09, val, horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':500, 'size':14})
    
#график топ жанров
plt.subplot(1,2,2)
sns.barplot(data=df, x=main_topic, y=main_topic.index, color='#A1EAFB')
plt.subplots_adjust(wspace=0.3, hspace=0)
plt.title('Топ жанров по кол-ву блогеров')
plt.xlabel('')
plt.xticks([])
for i, val in enumerate(main_topic.values):
    plt.text(val-1, i+0.14, val, horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':500, 'size':14})
    
plt.show()

# %% [markdown]
# Отлично, теперь мы знаем в какой стране больше всего блогеров из топ 200 (US), и какие категории каналов и жанры наиболее часто выбирают крупные блогеры. Давайте посмотрим как распределяются категории и жанры в US:

# %%
main_topic = df[df['Country']=='US']['Main topic'].value_counts().head(10)
category = df[df['Country']=='US']['Category'].value_counts()

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.barplot(data=df, x=category, y=category.index, color='#FFCEF3')
plt.title('Топ категорий в US')
plt.xlabel('')
plt.xticks([])
for i, val in enumerate(category.values):
    plt.text(val-1, i+0.09, val, horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':500, 'size':14})

plt.subplot(1,2,2)
sns.barplot(data=df, x=main_topic, y=main_topic.index, color='#A1EAFB')
plt.subplots_adjust(wspace=0.3, hspace=0)
plt.title('Топ жанров в US')
plt.xlabel('')
plt.xticks([])
for i, val in enumerate(main_topic.values):
    plt.text(val-0.5, i+0.14, val, horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':500, 'size':14})
plt.show()

# %% [markdown]
# Далее посмотрим какой какие каналы имееют наибольшое количество лайков/подписок/комментариев/вовлеченность:

# %%
more_like_channel = df.groupby('Channel Name')['Likes'].sum().nlargest(5)
more_followers_channel = df.groupby('Channel Name')['followers'].sum().nlargest(5)
more_views_channel = df.groupby('Channel Name')['Views'].sum().nlargest(5)
more_engr_channel = df.groupby('Channel Name')['Engagement Rate'].sum().nlargest(5)

sns.set(style="whitegrid", font='Segoe UI',font_scale=1.15,rc=custom_params)
plt.figure(figsize=(20,15))

#топ блогеров по лайкам
plt.subplot(2,2,1)
plt.subplots_adjust(wspace=0.3, hspace=0)
sns.barplot(data=df, x=more_like_channel, y=more_like_channel.index, color='#A1EAFB')
plt.title('Кол-во лайков')
plt.xlabel('')
plt.ylabel('')
plt.xticks([0.00e+09,0.50e+09,1.00e+09,1.50e+09,2.00e+09],labels = ['0 M','500 M','1 Bn','1.5 Bn','2 Bn'])

#топ блогеров по подписчикам
plt.subplot(2,2,2)
plt.subplots_adjust(wspace=0.5, hspace=0)
sns.barplot(data=df, x=more_followers_channel, y=more_followers_channel.index, color='#A1EAFB')
plt.title('Кол-во подписчиков')
plt.xlabel('')
plt.ylabel('')
plt.xticks([0.00e+08,0.50e+08,1.00e+08,1.50e+08,2.00e+08],labels = ['0 M','50 M','100 M','150 M','200 M'])

#топ блогеров по просмотрам
plt.subplot(2,2,3)
plt.subplots_adjust(wspace=0.3, hspace=0.2)
sns.barplot(data=df, x=more_views_channel, y=more_views_channel.index, color='#A1EAFB')
plt.title('Кол-во просмотров')
plt.xlabel('')
plt.ylabel('')
plt.xticks([0.00e+11,0.50e+11,1.00e+11,1.50e+11,2.00e+11],labels = ['0 M','50 Bn','100 Bn','150 Bn','200 Bn'])

#топ блогеров по вовлеченности
plt.subplot(2,2,4)
plt.subplots_adjust(wspace=0.4, hspace=0.2)
sns.barplot(data=df, x=more_engr_channel, y=more_engr_channel.index, color='#A1EAFB')
plt.title('Коэффициент вовлеченности')
plt.xlabel('')
plt.ylabel('')

plt.show()

# %% [markdown]
# Из графиков, видно, что канал с наибольшим количеством подписчиков - T-Series, при этом он лидирует и по количеству просмотров. Можно заметить, что 3 блогера из топ 5 по количеству подписчиков попали в топ 5 по количеству просмотров. Скорее всего количество просмотров зависит от количества подписчиков, проверим это:

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), cmap='cool', center=0, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Действительно, количество просмотров имеет достаточно большой коэффициент корреляции (0.83) с количеством подписчиков.
# Посмотрим какой жанр видео получает наибольшее количество лайков:

# %%
more_likes_genre = df.groupby('Main topic')['Likes'].sum().nlargest(5)
more_views_genre = df.groupby('Main topic')['Views'].sum().nlargest(5)

plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
plt.subplots_adjust(wspace=0.3, hspace=0)
sns.barplot(data=df, x=more_likes_genre, y=more_likes_genre.index, color='#CABBE9')
plt.title('Жанры с наибольшим количеством лайков')
plt.xlabel('')
plt.ylabel('')
plt.xticks([0.00e+09,2.00e+09,4.00e+09,6.00e+09,8.00e+09],labels = ['0M','2 Bn','4 Bn','6 Bn','8 Bn'])

plt.subplot(1,2,2)
sns.barplot(data=df, x=more_views_genre, y=more_views_genre.index, color='#CABBE9')
plt.title('Жанры с наибольшим количеством просмотров')
plt.xlabel('')
plt.ylabel('')
plt.xticks([0.00e+11,2.00e+11,4.00e+11,6.00e+11,8.00e+11],labels = ['0 M','200 Bn','400 Bn','600 Bn','800 Bn'])

plt.show()

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе анализа полученного датасета мы получили следующие результаты:
# * <b>География:</b> Самое больше количество крупнейших YouTube блогеров сосредоточено в US (их 67, что составляет 34% от Топ 200).
# * <b>Категории и жанры выбираемые блогерами:</b> Наиболее частовстречаемая категория у блогеров  - Gaming & Apps (48%), а жанры - Music (18%) и Entertainment (15%). Если смотреть по самому крупному региону (US), то категории не меняются, а в жанрах на первое место выходит Lifestyle.
# * <b>Самый крупный блогер по количеству подписчиков:</b> T-series (> 200 M подписчиков)
# * <b>Самый крупный блогер по количеству просмотров:</b> T-series (>150 Bn просмотров)
# * <b>Самый крупный блогер по количеству лайков:</b> PewDiePie (>2 Bn лайков)
# * <b>Канал с наибольшей вовлеченностью:</b> Galinha Pintadinha
# * <b>Жанр с наибольшим количеством лайков:</b> Lifestyle (>8 Bn лайков)
# * <b>Жанр с наибольшим количеством просмотров:</b> Music (>700 Bn просмотров)
#
# В ходе анализа была выдвинута гипотеза о зависимости количества просмотров на канале от количества подписчиков. Рассчитав коэффициент корреляции получили 0.83, что подтверждает нашу гипотезу.
